# %% [markdown]
# # 13.1: Playing Sound Waves in Python

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

import numpy as np
from ch13.functions import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#from math import sin, cos, pi
from sympy.core import *
from sympy.core.core import *
from sympy import *
#init_printing(use_unicode=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Playing first random sound:

# %%
import pygame, pygame.sndarray
pygame.mixer.init(frequency=44100, size=-16, channels=1)
arr = np.random.randint(-32768, 32767, size=44100, dtype="int16")
sound = pygame.sndarray.make_sound(arr)
sound.play()

# %% [markdown]
# Plotting random sound:

# %%
plot_sequence(arr, max=100)

# %%
plot_sequence(arr, max=100, line=True)

# %% [markdown]
# Playing a quieter sound

# %%
arr = np.random.randint(-10000, 10000, size=44100, dtype='int16')
plot_sequence(arr, max=100, line=True)
sound = pygame.sndarray.make_sound(arr)
sound.play()

# %% [markdown]
# Repeating sound:

# %%
form = np.repeat([10000, -10000], 50)
print(len(form))
plot_sequence(form)
# Out:
# 100

# %%
arr = np.tile(form, 441)
arr = np.array(arr, dtype='int16')
plot_sequence(arr, line=True, max=200)

# %%
sound = pygame.sndarray.make_sound(arr)
sound.play()

# %% [markdown]
# Exercise 13.1: Our musical note A was a pattern that repeated 441 times in one second. Create a similar pattern that
# repeats 350 times in one second, which produces the musical note F.

# %%
form = np.repeat([10000, -10000], 63) # resulting in a 126 element array
arr = np.tile(form, 350) # 126 * 350 = 44100
arr = np.array(arr, dtype='int16')
plot_sequence(arr, line=True, max=63 * 4)

# %%
sound = pygame.sndarray.make_sound(arr)
sound.play()
