# %% [markdown]
# # 13.2: Turning Sinusoidal waves into sounds

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

import numpy as np
from ch13.functions import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from math import sin, cos, pi, tan
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pygame, pygame.sndarray
pygame.mixer.init(frequency=44100, size=-16, channels=1)

# %%
plot_function(make_sinusoid(5, 4), 0, 1)

# %% [markdown]
# Playing sinusoid

# %%
sinusoid = make_sinusoid(441,8000)
arr = sample(sinusoid, 0, 1, 44100)
plot_sequence(arr)
sound = pygame.sndarray.make_sound(arr)
sound.play()

# %% [markdown]
# Exercise 13.2: Plot the tangent function tan(t) = sin(t)/cos(t). What is its period?

# %%
plot_function(tan, 0, 30)
plt.ylim(-10,10) #<1>
# Out:
# (-10.0, 10.0)

# %% [markdown]
# Exercise 13.3: What is the frequency of sin(3πt)? What is the period?

# %%
freq = (3*pi) / (2*pi)
freq
# Out:
# 1.5

# %% [markdown]
# Exercise 13.4: Find the value of k such that cos(kt) has a frequency of 5. Plot the resulting function cos(kt) from zero to
# one and show that it repeats itself 5 times.

# %%
k = 10*pi

plot_function(lambda t: cos(k*t), 0, 1)
