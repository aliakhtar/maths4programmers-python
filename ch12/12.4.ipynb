# %% [markdown]
# # 12.4: Gradient Ascent

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

import numpy as np
#from ch09.draw2d import *
from ch12.vectors import *
from ch12.functions import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#from math import sin, cos, pi
from sympy.core import *
from sympy.core.core import *
from sympy import *
#init_printing(use_unicode=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(gradient_ascent(landing_distance, 36, 83))
# Out:
# (37.581147519131584, 89.99992614263502)

# %% [markdown]
# Exercise 12.13: On the heatmap, simultaneously plot the paths of gradient ascent from 20 randomly chosen points. All
# of the paths should end up at one of the two maxima.

# %%
scalar_field_heatmap(landing_distance,35,40,80,100)
grad = gradient_ascent(landing_distance, 36, 83)
plt.scatter(36, 83, c='k', s=75)
plt.scatter(grad[0], grad[1], c='k', s=75)
plt.plot(*gradient_ascent_points(landing_distance, 36, 83))

# %%
from random import uniform

scalar_field_heatmap(landing_distance,0,90,0,360)
plt.xlabel('theta')
plt.ylabel('phi')
for _ in range(20):
    theta, phi = uniform(0, 90), uniform(0, 360)
    points = gradient_ascent_points(landing_distance, theta, phi )
    final = points[0][-1], points[1][-1]
    plt.plot(*points)
    plt.scatter(final[0], final[1])

plt.gcf().set_size_inches(9,7)

# %% [markdown]
# Exercise 12.16: How many steps does it take for gradient ascent to reach the origin from (36, 83)? Instead of jumping
# one gradient, jump 1.5 gradients. Show that you get there in fewer steps. What happens if you jump even further in
# each step?

# %%
print(count_gradient_ascent_steps(landing_distance, 36, 83, rate=1))
print(count_gradient_ascent_steps(landing_distance, 36, 83, rate=1.5))
# Out:
# 855
# 568
