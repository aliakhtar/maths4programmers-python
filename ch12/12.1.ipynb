# %% [markdown]
# # 12.1: Testing Projectile simulation

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

import numpy as np
#from ch09.draw2d import *
from ch12.vectors import *
from ch12.functions import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from math import sin, cos, pi
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Plotting trajectories

# %%
plot_trajectories(
    trajectory(45),
    trajectory(60)
)

# %% [markdown]
# ## Testing the effect of different angles on the landing position

# %%
angles = range(0,90, 5)
land_positions = [landing_position(trajectory(t)) for t in angles]
plt.scatter(angles, land_positions)

# %% [markdown]
# Exercise 12.1: How far does the cannonball go when fired at an angle of 50° from an initial height of zero? How about
# if it is fired at an angle of 130°?

# %%
print(landing_position(trajectory(50)))
print(landing_position(trajectory(130)))
# Out:
# 39.852831800565454
# -39.852831800565454

# %% [markdown]
# Exercise 12.3: Make a scatter plot of hang time versus angle for angles between 0 and 180°. Which launch angle
# produces the maximum hang time?

# %%
angles = range(0, 181, 5)
times = [hang_time(trajectory(a)) for a in angles]
plt.scatter(angles, times)

# %% [markdown]
# Mini-project 12.4: Write a function plot_trajectory_metric that plots the result of any metric we want over a
# given set of theta (θθ) values. For instance,
#
# `plot_trajectory_metric(landing_position,[10,20,30])`

# %%
plot_trajectory_metric(landing_position,[10,20,30])

# %%
plot_trajectory_metric(landing_position,range(0,90,5), height=10)

# %%
traj = trajectory(45)
plt.plot(traj[0], traj[2])
for i in range(0, 5):
    print((traj[0][i], traj[2][i]))
# Out:
# (0, 0)
# (0.1, 1.316113562373095)
# (0.2, 2.53412712474619)
# (0.30000000000000004, 3.654040687119285)
# (0.4, 4.67585424949238)
