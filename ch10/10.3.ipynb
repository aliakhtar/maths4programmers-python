# %% [markdown]
# # 10.3: Finding derivatives

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

import numpy as np
import matplotlib as plt
#from ch09.vectors import *
#from ch09.draw2d import *
from ch10.functions import *
from ch10.expressions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Exercise 10.15: Show that the derivative of f(x) = x**5 is indeed f′(x) = 5x**4 by plotting the numerical derivative (using the
# derivative function from chapter 8) alongside the symbolic derivative f′(x) = 5x 4 .

# %%
from ch08.functions import plot_function, get_flow_rate_function
f = lambda x: x ** 5
d = lambda x: 5*x**4
plot_function(get_flow_rate_function(f, digits=4),0,10)

# %%
plot_function(d,0,10,c='red')
