# %% [markdown]
# # 8.1: Calculating average flow from volume

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

from ch07.vectors import *
from ch05.vector_drawing import *
import numpy as np
from ch08.functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Plotting volume

# %%
plot_volume(volume, 0, 10)

# %% [markdown]
# ## Plotting flow

# %%
plot_flow_rate(flow_rate, 0, 10)

# %%
# Avg flow rate between hrs 4 and 9
avg_flow_rate(volume, 4, 9)
# Out:
# 0.390625

# %% [markdown]
# Exercise 8.1: Suppose you start a road trip at noon when your odometer reads 77,641 miles, and you end your road trip
# at 4:30 in the afternoon with your odometer reading 77,905 miles. What was your average speed during the trip?

# %%
distance_travelled = 77905 - 77641
time_elapsed = 16.5 - 12 # 4:30 PM - 12 PM
distance_travelled / time_elapsed
# Out:
# 58.666666666666664

# %% [markdown]
# Exercise 8.2: Write a Python function secant_line(f,x1,x2) that takes a function f(x) and two values, x1 and
# x2, and that returns a new function representing a secant line over time. For instance, if you ran line =
# secant_line(f,x1,x2), then line(3) would give you the y value of the secant line at x = 3 .

# %%
line = secant_line(volume, 4, 9)
for i in range(4, 10):
    print(line(i), volume(i))

plot_volume(line, 4, 9)
# Out:
# 3.3 3.3
# 3.690625 3.315625
# 4.08125 3.425
# 4.471875 3.721875
# 4.8625 4.3
# 5.253125 5.253125

# %% [markdown]
# Exercise 8.3: Write a function that uses the code from the previous exercise to plot a secant line of a function f
# between two given points.

# %%
plot_volume(volume, 0, 10)
plot_secant(volume, 4, 9)
