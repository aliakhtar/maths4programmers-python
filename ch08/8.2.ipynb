# %% [markdown]
# # 8.2: Plotting flow over time

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

from ch07.vectors import *
from ch05.vector_drawing import *
import numpy as np
from ch08.functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Function to return intervals of avg flow rates between hrs

# %%
interval_flow_rates(volume, 0, 10, 1)
# Out:
# [(0, 0.578125),
#  (1, 0.296875),
#  (2, 0.109375),
#  (3, 0.015625),
#  (4, 0.015625),
#  (5, 0.109375),
#  (6, 0.296875),
#  (7, 0.578125),
#  (8, 0.953125),
#  (9, 1.421875)]

# %%
plot_interval_flow_rates(volume, 0, 10, 1)

# %%
plot_flow_rate(flow_rate, 0, 10)
plot_interval_flow_rates(volume, 0, 10, 1)

# %%
plot_flow_rate(flow_rate, 0, 10)
plot_interval_flow_rates(volume, 0, 10, 1/3)

# %% [markdown]
# Exercise 8.4: Plot the decreasing_volume flow rates over time at 0.5-hour intervals. When is its flow rate the
# lowest? That is, when is oil leaving the tank at the fastest rate?
