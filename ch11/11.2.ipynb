# %% [markdown]
# # 11.2: Adding gravity to the asteroid game

# %%
# %load_ext autoreload
# %autoreload 2
from jupyterthemes import jtplot
jtplot.style()

import numpy as np
import matplotlib as plt
#from ch09.draw2d import *
from ch11.vectors import *
from ch11.functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Exercise 11.1: Where do all of the vectors in the vector field (-2−x, 4−y) point? Plot the vector field to confirm your
# answer.

# %%
field = lambda x,y: (-2-x, 4-y)
plot_vector_field(field, -10, 10, -10, 10)
